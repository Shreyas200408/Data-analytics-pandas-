# %% [markdown]
# # DATE AND TIME

# %% [markdown]
# # TIME

# %%
# Time module gives the access to work with the data where time is given
# This also gives us opporunity to work around different types of clock
# The time module starts its time from "EPOCH", which begins at 00:00:00, 1st Jan 1970

# %%
import time

# %%
time.time()
# Out:
# 1759815154.3942058

# %%
time.ctime()
# Out:
# 'Tue Oct  7 11:03:06 2025'

# %%
time.ctime(1759815154.3942058)
# Out:
# 'Tue Oct  7 11:02:34 2025'

# %%
help(time.time())
# Out:
# Help on float object:
#
# class float(object)
#  |  float(x=0, /)
#  |
#  |  Convert a string or number to a floating point number, if possible.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __ceil__(self, /)
#  |      Return the ceiling as an Integral.
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floor__(self, /)
#  |      Return the floor as an Integral.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Formats the float according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
# ...

# %%
ab = time.time()

# %%
ab/60
# Out:
# 29330261.539461397

# %% [markdown]
# # STRUCT TIME FORMAT

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2025, tm_mon=10, tm_mday=7, tm_hour=11, tm_min=12, tm_sec=17, tm_wday=1, tm_yday=280, tm_isdst=0)

# %%
time.asctime()
# Out:
# 'Tue Oct  7 11:15:38 2025'

# %% [markdown]
# # STRFTIME

# %%
help(time.strftime)
# Out:
# Help on built-in function strftime in module time:
#
# strftime(...)
#     strftime(format[, tuple]) -> string
#
#     Convert a time tuple to a string according to a format specification.
#     See the library reference manual for formatting codes. When the time tuple
#     is not present, current time as returned by localtime() is used.
#
#     Commonly used format codes:
#
#     %Y  Year with century as a decimal number.
#     %m  Month as a decimal number [01,12].
#     %d  Day of the month as a decimal number [01,31].
#     %H  Hour (24-hour clock) as a decimal number [00,23].
#     %M  Minute as a decimal number [00,59].
#     %S  Second as a decimal number [00,61].
#     %z  Time zone offset from UTC.
#     %a  Locale's abbreviated weekday name.
#     %A  Locale's full weekday name.
#     %b  Locale's abbreviated month name.
#     %B  Locale's full month name.
#     %c  Locale's appropriate date and time representation.
# ...

# %%
# to convert the time to a format which is convenient for the analysis

# %%
x = time.strftime("%m-%d-%Y")
x
# Out:
# '10-07-2025'

# %%
x1 = time.strftime("%d/%B/%y")
x1
# Out:
# '07/October/25'

# %% [markdown]
# # DATETIME

# %%
import datetime

# %%
print(datetime.datetime(2025,10,7,11,24,45,350))
# Out:
# 2025-10-07 11:24:45.000350

# %%
x2 = datetime.datetime.today()
x2
# Out:
# datetime.datetime(2025, 10, 7, 11, 28, 38, 834223)

# %%
print(x2.weekday())
# Out:
# 1

# %%
print(x2.isoweekday())
# Out:
# 2

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2025, 10, 7, 11, 30, 0, 41251)

# %%
x2.month
# Out:
# 10

# %% [markdown]
# # TIME DELTA

# %%
x2
# Out:
# datetime.datetime(2025, 10, 7, 11, 28, 38, 834223)

# %%
tdelta = datetime.timedelta(days =7)
tdelta
# Out:
# datetime.timedelta(days=7)

# %%
x2 + tdelta
# Out:
# datetime.datetime(2025, 10, 14, 11, 28, 38, 834223)

# %%
x2 -tdelta
# Out:
# datetime.datetime(2025, 9, 30, 11, 28, 38, 834223)
